# %%
from matplotlib import pyplot as plotter
import matplotlib

# %%
# %matplotlib inline

# %%
plotData=[208.685, 215.620,230.553, 238.602, 258.722, 261.038  ]
sizes=[64,128,256,512,1024,2048]

# %%
plotter.figure(figsize=(12,6))
plotter.title("RTT variation with packet size")
plotter.xlabel("Packet Size")
plotter.ylabel("Avg RTT")
plotter.plot(sizes,plotData)

# %%
##nmap
time=["11:16", "13:35", "16:47", "20:20", "23:44", "01:23" ]
counts=[37,38,39,33,41,40]

# %%
plotter.figure(figsize=(12,6))
plotter.title("nmap count variation")
plotter.xlabel("time of day")
plotter.ylabel("count")
plotter.plot(time,counts)

# %%
import re
import pandas as pd
import numpy as np
from collections import Counter
filenames = ["ping_n.txt","ping_p.txt"]
for filename in filenames:
    with open(filename) as f:
        inFile=f.read();

    data = re.compile(".*time=(\d+.\d+) ms\n").findall(inFile)
    data = list(map(float,data))
#     print(data)
    #added
#     recounted = Counter(data)
#     print(recounted)
    
    # (b)  What  was  the  minimum,  maximum,  mean,  and  median  latency  of  the  pings  that  succeeded?  Ignore  pings  that failed in the calculation. 
    data  = pd.DataFrame(data);
    # rtt min/avg/max/mdev = 0.244/1.083/175.827/6.021 ms
    print (filename); print(data.describe())
    print ("Median \t%f" % data.median())    
    # (c) Plot graphs to visualize the normal distribution of the ping latencies. The goal here is to find a method to present the data in a way that is clear and easy to understand. 
    plotter.figure(figsize=(6,4))
    plotter.title(filename)
    plotter.xlabel("pings")
    plotter.ylabel("time (ms)")
    plotter.plot(data)
    
#     labels, values = zip(*recounted.items())
#     indexes = np.arange(len(labels))
#     width = 1
#     plotter.bar(indexes, values,width)
#     plotter.show()
    
    print()
# Out:
# ping_n.txt
#                 0
# count  960.000000
# mean     5.261795
# std      1.358752
# min      0.265000
# 25%      4.567500
# 50%      5.450000
# 75%      6.190000
# max      8.760000
# Median 	5.450000
#
# ping_p.txt
#                 0
# count  976.000000
# mean     4.356498
# std      1.445417
# min      0.262000
# 25%      3.570000
# 50%      4.580000
# 75%      5.440000
# max      7.440000
# Median 	4.580000

# %%
# import plotly.plotly as py
# from collections import Counter

# %%
import matplotlib.pyplot as plt

d = [1,2,3,100,1,1]
# An "interface" to matplotlib.axes.Axes.hist() method
n, bins, patches = plt.hist(x=d, bins='auto', color='#0504aa',
                            alpha=0.7, rwidth=0.85)
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('My Very Own Histogram')
# plt.text(23, 45, r'$\mu=15, b=3$')
maxfreq = n.max()
# Set a clean upper y-axis limit.
plt.ylim(top=np.ceil(maxfreq / 10) * 10 if maxfreq % 10 else maxfreq + 10)
# Out:
# (0.0, 10.0)

# %%
import re
import pandas as pd
import numpy as np
from collections import Counter
filenames = ["ping_n.txt"]
for filename in filenames:
    with open(filename) as f:
        inFile=f.read();

    data = re.compile(".*time=(\d+.\d+) ms\n").findall(inFile)
    d = list(map(float,data))
    n, bins, patches = plt.hist(x=d, bins='auto', color='#0504aa',
                            alpha=0.7, rwidth=0.85)
    plt.grid(axis='y', alpha=0.75)
    plt.xlabel('ping latency(in ms)')
    plt.ylabel('Frequency')
    plt.title('ping -n -c1000 ')
    # plt.text(23, 45, r'$\mu=15, b=3$')
    maxfreq = n.max()
    # Set a clean upper y-axis limit.
    plt.ylim(top=np.ceil(maxfreq / 10) * 10 if maxfreq % 10 else maxfreq + 10)
#     print("next")
    print()

# %%
filenames = ["ping_p.txt"]
for filename in filenames:
    with open(filename) as f:
        inFile=f.read();

    data = re.compile(".*time=(\d+.\d+) ms\n").findall(inFile)
    d = list(map(float,data))
    n, bins, patches = plt.hist(x=d, bins='auto', color='#0504aa',
                            alpha=0.7, rwidth=0.85)
    plt.grid(axis='y', alpha=0.75)
    plt.xlabel('ping latency(in ms)')
    plt.ylabel('Frequency')
    plt.title('ping -p ff00 -c1000 ')
    # plt.text(23, 45, r'$\mu=15, b=3$')
    maxfreq = n.max()
    # Set a clean upper y-axis limit.
    plt.ylim(top=np.ceil(maxfreq / 10) * 10 if maxfreq % 10 else maxfreq + 10)
#     print("next")
    print()

# %%
import re
import pandas as pd
import numpy as np
from collections import Counter
filenames = ["intra1.txt"]
for filename in filenames:
    with open(filename) as f:
        inFile=f.read();

    data = re.compile(".*time=(\d+.\d+) ms\n").findall(inFile)
    d = list(map(float,data))
    n, bins, patches = plt.hist(x=d, bins=600, color='#0504aa',
                            alpha=0.7, rwidth=0.85)
    plt.grid(axis='y', alpha=0.75)
    plt.xlabel('ping latency(in ms)')
    plt.ylabel('Frequency')
    plt.title('ping -n -c1000 ')
    # plt.text(23, 45, r'$\mu=15, b=3$')
    maxfreq = n.max()
    # Set a clean upper y-axis limit.
    plt.ylim(top=np.ceil(maxfreq / 10) * 10 if maxfreq % 10 else maxfreq + 10)
#     plt.xlim(
#     print("next")
    print()

# %%
import re
import pandas as pd
import numpy as np
from collections import Counter
filenames = ["intra2.txt"]
for filename in filenames:
    with open(filename) as f:
        inFile=f.read();

    data = re.compile(".*time=(\d+.\d+) ms\n").findall(inFile)
    d = list(map(float,data))
    n, bins, patches = plt.hist(x=d, bins=80, color='#0504aa',
                            alpha=0.7, rwidth=0.85)
    plt.grid(axis='y', alpha=0.75)
    plt.xlabel('ping latency(in ms)')
    plt.ylabel('Frequency')
    plt.title('ping -n -c1000 ')
    # plt.text(23, 45, r'$\mu=15, b=3$')
    maxfreq = n.max()
    # Set a clean upper y-axis limit.
    plt.ylim(top=np.ceil(maxfreq / 10) * 10 if maxfreq % 10 else maxfreq + 10)
#     print("next")
    print()
